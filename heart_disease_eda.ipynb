# %% [markdown]
# # Heart Disease Data Analysis

# %% [markdown]
# ## Setup and Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load and Clean Data

# %%
#load csv file using pandas
pd.read_csv('processed_cleveland.data')
